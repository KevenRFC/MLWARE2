# %% [markdown]
# # MLWARE 2 - Recommendation Challenge

# %% [markdown]
# This was a challenge organized for Analytics Vidhya that lasted 60 hours. It started at Feb 22 2017.
#
# The link of the challenge: https://datahack.analyticsvidhya.com/contest/mlware-2/

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Understanding customers and their preferences is the holy grail for online businesses. Building a recommender system is one of the common ways to do so.
# In this contest, you need to build a model that predicts a given user’s ratings (from 0 to 10 stars) for a given item based on past ratings on other items and/or other information. The problem of rating prediction is the primary part of a recommendation problem (the part where explicit ratings are given). No additional information (user demographics, item content features etc.) are given and the prediction has to be made using only the ratings of already rated items.

# %% [markdown]
# ### Dataset:
# The rating data of 40,000 users, and 120 items . Ratings of users who have rated less than 10 items have been removed.
#
# 1.- training.csv - This contains 958,529 ratings which are selected randomly from 1,599,544 ratings. Contains 4 columns:
#
#     ID - Unique ID for each record
#     userId - Unique user ID for each customer
#     itemid - Item ID fo the product
#     rating - Rating given to each item by user
#
# 2.- test.csv - This file has three columns containing the ID, userId and itemId. The predictions on this set would be judged.
#
# ### Evaluation:
# The metrics used for evaluating the performance of the model is the "Root Mean Squared Error" (RMSE) between the predicted and the actual ratings.

# %% [markdown]
# # SOLUTION

# %% [markdown]
# In this solution, I will present how I have obtained an RMSE = 1.9858 in the testing data (30% original training data given for the problem).
#
# #### Autor: Keven Ronald Fernández Carrillo ( A passionate newbie in machine learning and data science topics )

# %% [markdown]
# # I. Import Data

# %%
# Import libraries
import pandas as pd
import numpy as np

# %%
# Load training and testing data
train_data = pd.read_csv("C:/Users/b33580/Documents/Python Scripts/MLWARE/TRAIN/train_MLWARE2.csv")
test_data = pd.read_csv("C:/Users/b33580/Documents/Python Scripts/MLWARE/TEST/test_MLWARE2.csv")

# %%
# Check info of training data
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958529 entries, 0 to 958528
# Data columns (total 4 columns):
# ID        958529 non-null object
# userId    958529 non-null int64
# itemId    958529 non-null int64
# rating    958529 non-null float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 29.3+ MB

# %%
# Check info of testing data (submitting data)
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641015 entries, 0 to 641014
# Data columns (total 3 columns):
# ID        641015 non-null object
# userId    641015 non-null int64
# itemId    641015 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 14.7+ MB

# %%
# Creating a DataFrame that will contain our own training and testing data
data = train_data
print("Shape: {}".format(data.shape))
# Out:
# Shape: (958529, 4)

# %% [markdown]
# # II. Feature Engineering

# %% [markdown]
# ##  II.1 User Set

# %% [markdown]
# We get started obtaining individually features per each user:

# %%
# Sort data by "userId" and "itemId"
data_user_temp = data.sort_values(by = ["userId","itemId"], ascending = [True,True])
data_user_temp.head(10)
# Out:
#            ID  userId  itemId  rating
# 488842    0_1       0       1     0.5
# 488839   0_28       0      28     1.5
# 488844   0_29       0      29     6.5
# 488841   0_47       0      47     2.0
# 488840  0_107       0     107     1.5
# 488845  0_121       0     121     6.0
# 488838  0_129       0     129     1.0
# 488843  0_137       0     137     6.0
# 438447    1_1       1       1     7.0
# 438496    1_3       1       3     8.0

# %%
# Reset index
data_user_temp.reset_index(inplace = True, drop = True)
data_user_temp.head(5)
# Out:
#       ID  userId  itemId  rating
# 0    0_1       0       1     0.5
# 1   0_28       0      28     1.5
# 2   0_29       0      29     6.5
# 3   0_47       0      47     2.0
# 4  0_107       0     107     1.5

# %% [markdown]
# We'll obtain per each userId: count, mean, median, min, max and std of their ratings

# %%
data_user = pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].count()), 
                         columns = ["userId","rat_count_user"])

data_user = pd.concat([data_user,
                       pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].mean()), 
                       columns = ["userId","rat_mean_user"])["rat_mean_user"],
                       pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].median()), 
                       columns = ["userId","rat_median_user"])["rat_median_user"],
                       pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].min()), 
                       columns = ["userId","rat_min_user"])["rat_min_user"],
                       pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].max()), 
                       columns = ["userId","rat_max_user"])["rat_max_user"],
                       pd.DataFrame(np.array(data_user_temp.groupby("userId", as_index = False, axis = 0)["rating"].std()), 
                       columns = ["userId","rat_std_user"])["rat_std_user"] ], 
                       axis = 1)
data_user_temp = [] #Restart the temporal variable

data_user.head(10)
# Out:
#    userId  rat_count_user  rat_mean_user  rat_median_user  rat_min_user  \
# 0       0               8       3.125000             1.75           0.5
# 1       1              70       7.314286             8.00           2.0
# 2       2              11       3.090909             0.50           0.0
# 3       4              10       8.550000             8.50           8.0
# 4       5              13       5.269231             5.50           2.5
# 5       6              26       2.076923             1.50           0.0
# 6       7              22       3.590909             4.25           0.5
# 7       8              52       6.413462             6.25           3.5
# 8       9              11       5.909091             7.00           1.0
# 9      10              50       6.710000             7.50           0.0
#
#    rat_max_user  rat_std_user
# 0           6.5      2.559994
# 1           9.5      1.558454
# 2           8.5      3.277333
# 3           9.0      0.437798
# 4           7.5      1.494649
# 5           5.5      1.677452
# 6           7.0      2.152719
# 7          10.0      1.247433
# 8           8.5      2.508168
# 9          10.0      3.136503

# %% [markdown]
# ##  II.2 Item Set

# %% [markdown]
# Next we get individually features per each item:

# %%
# Sort data by "itemId" and "userId"
data_item_temp = data.sort_values(by = ["itemId","userId"], ascending = [True,True])
data_item_temp.head(10)
# Out:
#           ID  userId  itemId  rating
# 488842   0_1       0       1     0.5
# 438447   1_1       1       1     7.0
# 62369    4_1       4       1     9.0
# 175260   5_1       5       1     5.0
# 525179   6_1       6       1     1.5
# 5596     7_1       7       1     4.5
# 711690   8_1       8       1     5.5
# 871059  10_1      10       1     8.5
# 223519  16_1      16       1     1.5
# 18231   18_1      18       1     0.0

# %%
# Reset index
data_item_temp.reset_index(inplace = True, drop = True)
data_item_temp.head(5)
# Out:
#     ID  userId  itemId  rating
# 0  0_1       0       1     0.5
# 1  1_1       1       1     7.0
# 2  4_1       4       1     9.0
# 3  5_1       5       1     5.0
# 4  6_1       6       1     1.5

# %% [markdown]
# We obtain per each intemId: rating count, mean, median, min, max and std of the ratings given from users:

# %%
data_item = pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].count()), 
                         columns = ["itemId","rat_count_item"])
data_item = pd.concat([data_item,
                       pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].mean()), 
                       columns = ["itemId","rat_mean_item"])["rat_mean_item"],
                       pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].median()), 
                       columns = ["itemId","rat_median_item"])["rat_median_item"],
                       pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].min()), 
                       columns = ["itemId","rat_min_item"])["rat_min_item"],
                       pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].max()), 
                       columns = ["itemId","rat_max_item"])["rat_max_item"],
                       pd.DataFrame(np.array(data_item_temp.groupby("itemId", as_index = False, axis = 0)["rating"].std()), 
                       columns = ["itemId","rat_std_item"])["rat_std_item"] ], 
                       axis = 1)
data_item_temp = [] #Restart the temporal variable
data_item.head(10)
# Out:
#    itemId  rat_count_item  rat_mean_item  rat_median_item  rat_min_item  \
# 0       1           23934       5.377288              5.5           0.0
# 1       2            7393       6.247531              6.5           0.0
# 2       3            8479       6.547647              7.0           0.0
# 3       4            3569       5.626086              6.0           0.0
# 4       5            3028       4.777576              5.0           0.0
# 5       6            3319       5.293010              5.5           0.0
# 6       7            4642       5.950883              6.0           0.0
# 7       8            7881       6.510088              6.5           0.0
# 8      10           23706       4.693917              5.0           0.0
# 9      11            5603       5.819115              6.0           0.0
#
#    rat_max_item  rat_std_item
# 0          10.0      2.638525
# 1          10.0      2.425138
# 2          10.0      2.456252
# 3          10.0      2.467517
# 4          10.0      2.979029
# 5          10.0      2.763852
# 6          10.0      2.586920
# 7          10.0      2.361828
# 8          10.0      2.696327
# 9          10.0      2.843468

# %% [markdown]
# Check if there are null values:

# %%
print (data_user.isnull().sum() )
# Out:
# userId             0
# rat_count_user     0
# rat_mean_user      0
# rat_median_user    0
# rat_min_user       0
# rat_max_user       0
# rat_std_user       6
# dtype: int64

# %% [markdown]
# There are null values, then we check each row that have null values:

# %%
data_user[data_user["rat_std_user"].isnull()]
# Out:
#        userId  rat_count_user  rat_mean_user  rat_median_user  rat_min_user  \
# 4628     6615               1            7.0              7.0           7.0
# 8631    13046               1            9.0              9.0           9.0
# 16782   27746               1            5.0              5.0           5.0
# 18319   29589               1            6.5              6.5           6.5
# 21332   33146               1            4.0              4.0           4.0
# 30872   44813               1            0.0              0.0           0.0
#
#        rat_max_user  rat_std_user
# 4628            7.0           NaN
# 8631            9.0           NaN
# 16782           5.0           NaN
# 18319           6.5           NaN
# 21332           4.0           NaN
# 30872           0.0           NaN

# %% [markdown]
# For these null values we'll replace with "0", because the std for these rows are 0 individually(1 row for each userId):

# %%
data_user["rat_std_user"] = data_user["rat_std_user"].fillna(0)

# %% [markdown]
# Then now we have ...

# %%
print (data_user.isnull().sum() )
# Out:
# userId             0
# rat_count_user     0
# rat_mean_user      0
# rat_median_user    0
# rat_min_user       0
# rat_max_user       0
# rat_std_user       0
# dtype: int64

# %% [markdown]
# ## II.3 Join between initial DataFrame and created DataFrames

# %% [markdown]
# Adding the user and item features to our initial dataframe:

# %%
# User Feactures
dataset_temp = pd.merge(data, data_user, how="left", on = "userId")
# Item Feactures
dataset = pd.merge(dataset_temp, data_item, how="left", on = "itemId")

dataset_temp = [] #Restart the temporal variable

dataset.head(50)
# Out:
#            ID  userId  itemId  rating  rat_count_user  rat_mean_user  \
# 0   16041_129   16041     129     0.5              29       5.862069
# 1    16041_25   16041      25     0.5              29       5.862069
# 2    16041_28   16041      28     5.5              29       5.862069
# 3   16041_101   16041     101     0.5              29       5.862069
# 4    16041_47   16041      47     1.5              29       5.862069
# 5   16041_132   16041     132     0.5              29       5.862069
# 6    16041_38   16041      38     0.5              29       5.862069
# 7    16041_89   16041      89    10.0              29       5.862069
# 8    16041_17   16041      17     2.5              29       5.862069
# 9   16041_116   16041     116     6.5              29       5.862069
# 10   16041_56   16041      56     6.0              29       5.862069
# 11   16041_29   16041      29     5.0              29       5.862069
# 12  16041_112   16041     112     8.0              29       5.862069
# 13   16041_64   16041      64     9.5              29       5.862069
# 14  16041_118   16041     118     9.5              29       5.862069
# 15   16041_23   16041      23     9.5              29       5.862069
# 16   16041_20   16041      20     9.5              29       5.862069
# 17  16041_124   16041     124     9.5              29       5.862069
# 18   16041_43   16041      43     9.5              29       5.862069
# 19    16041_3   16041       3     9.5              29       5.862069
# 20  16041_115   16041     115     9.5              29       5.862069
# 21   16041_18   16041      18     9.5              29       5.862069
# 22  16041_111   16041     111     5.0              29       5.862069
# 23   16041_73   16041      73     5.0              29       5.862069
# 24   16041_81   16041      81     5.0              29       5.862069
# 25   16041_61   16041      61     5.0              29       5.862069
# 26   16041_75   16041      75     5.0              29       5.862069
# 27   16041_27   16041      27     5.0              29       5.862069
# 28   16041_14   16041      14     7.0              29       5.862069
# 29  56092_129   56092     129    10.0              13       7.000000
# 30   56092_28   56092      28     5.0              13       7.000000
# 31  56092_101   56092     101    10.0              13       7.000000
# 32    56092_1   56092       1     0.0              13       7.000000
# 33   56092_27   56092      27    10.0              13       7.000000
# 34    56092_3   56092       3    10.0              13       7.000000
# 35   56092_35   56092      35     2.5              13       7.000000
# 36  56092_137   56092     137    10.0              13       7.000000
# 37   56092_83   56092      83     7.5              13       7.000000
# 38   56092_73   56092      73     7.5              13       7.000000
# 39  56092_115   56092     115     4.0              13       7.000000
# 40   56092_75   56092      75     5.0              13       7.000000
# 41  56092_120   56092     120     9.5              13       7.000000
# 42   3498_129    3498     129     0.0               8       1.937500
# 43    3498_25    3498      25     1.5               8       1.937500
# 44    3498_10    3498      10     4.0               8       1.937500
# 45    3498_47    3498      47     0.0               8       1.937500
# 46     3498_1    3498       1     0.0               8       1.937500
# 47    3498_34    3498      34     5.0               8       1.937500
# 48    3498_51    3498      51     5.0               8       1.937500
# 49   3498_135    3498     135     0.0               8       1.937500
#
#     rat_median_user  rat_min_user  rat_max_user  rat_std_user  rat_count_item  \
# 0              5.50           0.5          10.0      3.390893           23951
# 1              5.50           0.5          10.0      3.390893           23844
# 2              5.50           0.5          10.0      3.390893           23988
# 3              5.50           0.5          10.0      3.390893           23976
# 4              5.50           0.5          10.0      3.390893           23891
# 5              5.50           0.5          10.0      3.390893            4468
# 6              5.50           0.5          10.0      3.390893            4046
# 7              5.50           0.5          10.0      3.390893            9977
# 8              5.50           0.5          10.0      3.390893            3583
# 9              5.50           0.5          10.0      3.390893           11737
# 10             5.50           0.5          10.0      3.390893           13028
# 11             5.50           0.5          10.0      3.390893           13220
# 12             5.50           0.5          10.0      3.390893           10027
# 13             5.50           0.5          10.0      3.390893            8677
# 14             5.50           0.5          10.0      3.390893            6366
# 15             5.50           0.5          10.0      3.390893           10800
# 16             5.50           0.5          10.0      3.390893            6685
# 17             5.50           0.5          10.0      3.390893           12092
# 18             5.50           0.5          10.0      3.390893           13673
# 19             5.50           0.5          10.0      3.390893            8479
# 20             5.50           0.5          10.0      3.390893            9548
# 21             5.50           0.5          10.0      3.390893           12090
# 22             5.50           0.5          10.0      3.390893            5407
# 23             5.50           0.5          10.0      3.390893            8491
# 24             5.50           0.5          10.0      3.390893            5535
# 25             5.50           0.5          10.0      3.390893            9318
# 26             5.50           0.5          10.0      3.390893            5592
# 27             5.50           0.5          10.0      3.390893            5659
# 28             5.50           0.5          10.0      3.390893            6543
# 29             7.50           0.0          10.0      3.391165           23951
# 30             7.50           0.0          10.0      3.391165           23988
# 31             7.50           0.0          10.0      3.391165           23976
# 32             7.50           0.0          10.0      3.391165           23934
# 33             7.50           0.0          10.0      3.391165            5659
# 34             7.50           0.0          10.0      3.391165            8479
# 35             7.50           0.0          10.0      3.391165           10190
# 36             7.50           0.0          10.0      3.391165           15353
# 37             7.50           0.0          10.0      3.391165           11523
# 38             7.50           0.0          10.0      3.391165            8491
# 39             7.50           0.0          10.0      3.391165            9548
# 40             7.50           0.0          10.0      3.391165            5592
# 41             7.50           0.0          10.0      3.391165            6675
# 42             0.75           0.0           5.0      2.336626           23951
# 43             0.75           0.0           5.0      2.336626           23844
# 44             0.75           0.0           5.0      2.336626           23706
# 45             0.75           0.0           5.0      2.336626           23891
# 46             0.75           0.0           5.0      2.336626           23934
# 47             0.75           0.0           5.0      2.336626            5094
# 48             0.75           0.0           5.0      2.336626            4143
# 49             0.75           0.0           5.0      2.336626            5807
#
#     rat_mean_item  rat_median_item  rat_min_item  rat_max_item  rat_std_item
# 0        4.027619              3.5           0.0          10.0      2.674620
# 1        4.677403              5.0           0.0          10.0      2.561905
# 2        4.290770              4.0           0.0          10.0      2.656385
# 3        5.368702              5.5           0.0          10.0      2.640348
# 4        4.935101              5.0           0.0          10.0      2.550463
# 5        5.660586              6.0           0.0          10.0      2.564918
# 6        5.540040              5.5           0.0          10.0      2.564231
# 7        6.646637              7.0           0.0          10.0      2.368218
# 8        5.460787              5.5           0.0          10.0      2.679421
# 9        6.713002              7.0           0.0          10.0      2.155627
# 10       6.868322              7.0           0.0          10.0      2.189291
# 11       6.700983              7.0           0.0          10.0      2.339766
# 12       6.654134              7.0           0.0          10.0      2.176222
# 13       6.400484              6.5           0.0          10.0      2.255872
# 14       6.290606              6.5           0.0          10.0      2.612012
# 15       6.414769              6.5           0.0          10.0      2.395125
# 16       5.806806              6.0           0.0          10.0      2.705643
# 17       6.796973              7.0           0.0          10.0      2.291321
# 18       6.874826              7.0           0.0          10.0      2.215489
# 19       6.547647              7.0           0.0          10.0      2.456252
# 20       6.411186              6.5           0.0          10.0      2.422566
# 21       6.605997              7.0           0.0          10.0      2.505588
# 22       5.798687              6.0           0.0          10.0      2.564092
# 23       6.541338              7.0           0.0          10.0      2.289462
# 24       5.373803              5.5           0.0          10.0      2.537649
# 25       6.696984              7.0           0.0          10.0      2.289470
# 26       6.017525              6.5           0.0          10.0      2.722328
# 27       6.214172              6.5           0.0          10.0      2.509418
# 28       5.979826              6.0           0.0          10.0      2.592668
# 29       4.027619              3.5           0.0          10.0      2.674620
# 30       4.290770              4.0           0.0          10.0      2.656385
# 31       5.368702              5.5           0.0          10.0      2.640348
# 32       5.377288              5.5           0.0          10.0      2.638525
# 33       6.214172              6.5           0.0          10.0      2.509418
# 34       6.547647              7.0           0.0          10.0      2.456252
# 35       6.633660              7.0           0.0          10.0      2.326288
# 36       6.779066              7.0           0.0          10.0      2.345042
# 37       6.739478              7.0           0.0          10.0      2.206272
# 38       6.541338              7.0           0.0          10.0      2.289462
# 39       6.411186              6.5           0.0          10.0      2.422566
# 40       6.017525              6.5           0.0          10.0      2.722328
# 41       6.393483              6.5           0.0          10.0      2.490761
# 42       4.027619              3.5           0.0          10.0      2.674620
# 43       4.677403              5.0           0.0          10.0      2.561905
# 44       4.693917              5.0           0.0          10.0      2.696327
# 45       4.935101              5.0           0.0          10.0      2.550463
# 46       5.377288              5.5           0.0          10.0      2.638525
# 47       5.900864              6.0           0.0          10.0      2.546560
# 48       5.588342              6.0           0.0          10.0      2.608309
# 49       6.034441              6.0           0.0          10.0      2.361113

# %% [markdown]
# ## Split into training & test sets

# %% [markdown]
# We'll use 70% of the data for training and 30% for testing:

# %%
from sklearn import cross_validation
data_train , data_test = cross_validation.train_test_split(dataset, train_size = 0.70, random_state = 99)
print ("Train:", data_train.shape)
print ("Test: ", data_test.shape)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# Train: (670970, 16)
# Test:  (287559, 16)

# %%
# Identify Target:
variables_set_y = ['rating']

# Identify Features (The columns we'll use to predict the target):
variables_set_x = list(dataset.columns)
delete_var = ['rating','ID','userId','itemId'] # Features to delete

temp = []
for var in variables_set_x:
    if var not in delete_var:
        temp.append(var)
variables_set_x = temp
temp = []
print ("# Feactures: ", len(variables_set_x))
print ("Feactures: ")
variables_set_x
# Out:
# # Feactures:  12
# Feactures:
# ['rat_count_user',
#  'rat_mean_user',
#  'rat_median_user',
#  'rat_min_user',
#  'rat_max_user',
#  'rat_std_user',
#  'rat_count_item',
#  'rat_mean_item',
#  'rat_median_item',
#  'rat_min_item',
#  'rat_max_item',
#  'rat_std_item']

# %%
# Store separately X(features) and Y(target) for training and testing datasets
X_train = data_train.ix[:, variables_set_x]
y_train = data_train.ix[:, variables_set_y]

X_test = data_test.ix[:, variables_set_x]
y_test = data_test.ix[:, variables_set_y]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 670970 entries, 836349 to 684673
# Data columns (total 12 columns):
# rat_count_user     670970 non-null int64
# rat_mean_user      670970 non-null float64
# rat_median_user    670970 non-null float64
# rat_min_user       670970 non-null float64
# rat_max_user       670970 non-null float64
# rat_std_user       670970 non-null float64
# rat_count_item     670970 non-null int64
# rat_mean_item      670970 non-null float64
# rat_median_item    670970 non-null float64
# rat_min_item       670970 non-null float64
# rat_max_item       670970 non-null float64
# rat_std_item       670970 non-null float64
# dtypes: float64(10), int64(2)
# memory usage: 66.5 MB

# %% [markdown]
# ## III. Modeling

# %% [markdown]
# First, we'll train and test with RandomForestRegressor and ExtraTreesRegressor models individually:

# %% [markdown]
# ## III.1 Individual Models

# %% [markdown]
# ### A. Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Show RandomForestRegressor's parameters
RandomForestRegressor()
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False)

# %%
# Initialize our RandomForestRegressor  
# n_estimators: is the number of trees in the forest.
# min_samples_split: is the minimum number of rows we need to make a split
# min_samples_leaf: is the minimum number of samples we can have at the place where a tree branch ends (the bottom points of the tree)
# criterion: the function to measure the quality of a split.
# random_state: is the seed used by the random number generator
# n_jobs: the number of jobs to run in parallel for both fit and predict
rfr_model = RandomForestRegressor(n_estimators = 50, criterion='mse', random_state=100, n_jobs=-1, 
                                  min_samples_leaf=4, min_samples_split=8)

# %%
# We'll calculate the running time
from time import time
time_star = time()

# Training our model:
rfr_model.fit(X_train, y_train)

time_end = time()
print ("Time: ", np.round((time_end-time_star)/60,2), " minutes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Time:  0.99  minutes

# %%
# Predict the target to our training and testing data
y_pred_rfr_train = rfr_model.predict(X_train)
y_pred_rfr = rfr_model.predict(X_test)

# %%
from sklearn import metrics
import numpy as np
print('Metrics for Training Set:')
print('MAE:', metrics.mean_absolute_error(y_train, y_pred_rfr_train))
print('MSE:', metrics.mean_squared_error(y_train, y_pred_rfr_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_rfr_train)))

print('\nMetrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_rfr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_rfr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rfr)))
# Out:
# Metrics for Training Set:
# MAE: 1.00914955162
# MSE: 1.90360949667
# RMSE: 1.37971355602
#
# Metrics for Test Set:
# MAE: 1.50396081277
# MSE: 4.10212944038
# RMSE: 2.0253714327

# %% [markdown]
# ### B. ExtraTrees Regressor

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Show ExtraTreesRegressor's parameters
ExtraTreesRegressor()
# Out:
# ExtraTreesRegressor(bootstrap=False, criterion='mse', max_depth=None,
#           max_features='auto', max_leaf_nodes=None,
#           min_impurity_split=1e-07, min_samples_leaf=1,
#           min_samples_split=2, min_weight_fraction_leaf=0.0,
#           n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#           verbose=0, warm_start=False)

# %%
# Initialize our ExtraTreesRegressor  
# n_estimators: is the number of trees in the forest.
# min_samples_split: is the minimum number of rows we need to make a split
# min_samples_leaf: is the minimum number of samples we can have at the place where a tree branch ends (the bottom points of the tree)
# criterion: the function to measure the quality of a split.
# random_state: is the seed used by the random number generator
# n_jobs: the number of jobs to run in parallel for both fit and predict
etr_model = ExtraTreesRegressor(n_estimators = 50, criterion='mse', random_state=100, n_jobs=-1,
                                  min_samples_leaf=4, min_samples_split=8)

# %%
# We'll calculate the running time
from time import time
time_star = time()

# Training our model:
etr_model.fit(X_train, y_train)

time_end = time()
print ("Time: ", np.round((time_end-time_star)/60,2), " minutes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Time:  0.59  minutes

# %%
# Predict the target to our training and testing data
y_pred_etr_train = etr_model.predict(X_train)
y_pred_etr = etr_model.predict(X_test)

# %%
from sklearn import metrics
import numpy as np
print('Metrics for Training Set:')
print('MAE:', metrics.mean_absolute_error(y_train, y_pred_etr_train))
print('MSE:', metrics.mean_squared_error(y_train, y_pred_etr_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_etr_train)))

print('\nMetrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_etr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_etr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_etr)))
# Out:
# Metrics for Training Set:
# MAE: 1.02168226937
# MSE: 1.92032092862
# RMSE: 1.38575644636
#
# Metrics for Test Set:
# MAE: 1.49539578074
# MSE: 4.05270048168
# RMSE: 2.01313200801

# %% [markdown]
# #### The best model between these models is ExtraTreesRegressor.

# %% [markdown]
# ## III.2 First simple ensemble model

# %% [markdown]
# To start, first we make a simple ensemble model with an simple average between the 2 predictions of our generated models:

# %%
y_pred = (y_pred_rfr + y_pred_etr)/2

# %%
print('Metrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Metrics for Test Set:
# MAE: 1.49429490222
# MSE: 4.03993119611
# RMSE: 2.00995800855

# %% [markdown]
# Now, we'll make an interation to coefficients that multiply the predictions of the models with values between 1 - 10 for finding the best

# %%
# At begin(above) "a" and "b" were:
a = 1
b = 1
# Now, "a" and "b" coefficients will be from 1 until 10 
array_mrse = []
for a in range(1,11):
    for b in range(1,11):
        var_sum = a + b
        y_pred = (y_pred_etr*a + y_pred_rfr*b)/var_sum
        rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
        array_mrse.append([a,b,rmse])
pd.DataFrame(array_mrse, columns = ['a','b','mrse']).sort_values(by = ['mrse','a']).head(5)
# Out:
#      a  b      mrse
# 10   2  1  2.008944
# 31   4  2  2.008944
# 52   6  3  2.008944
# 73   8  4  2.008944
# 94  10  5  2.008944

# %% [markdown]
# We can see that best combination of coefficients are: a = 2 and b = 1 and this assembling improve(decreasing the RMSE) the individual models.

# %% [markdown]
# ## III.3 Hyperparameters Tunning using GridSearch and CV k-folds

# %% [markdown]
# Now, we'll go tunning some parameters of the ExtraTreesRegressor model to improve our result. For that we use GridSearchCV:

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
from time import time
time_star = time()

n_estimators = list(np.arange(50, 251, 50)) #values = [50,100,150,200,250]
max_features = [None, 'sqrt', 'log2'] 

from sklearn.grid_search import GridSearchCV
etr_tunning = ExtraTreesRegressor(criterion='mse', random_state=100, n_jobs=-1, 
                                  min_samples_leaf=4, min_samples_split=8)
hyperparameters = {
                     'n_estimators' : n_estimators,
                     'max_features' : max_features
                  }

gridCV = GridSearchCV(etr_tunning , param_grid = hyperparameters, cv = 4, n_jobs = -1)

gridCV.fit(X_train, y_train)

print('Best score: {}'.format(gridCV.best_score_))
print('Best parameters: {}'.format(gridCV.best_params_))

time_end = time()
print ("Time: ", (time_end-time_star)/60, " minutes")
# Out:
# C:\Users\Keven\Anaconda3\lib\site-packages\sklearn\grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# C:\Users\Keven\Anaconda3\lib\site-packages\sklearn\grid_search.py:619: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   best_estimator.fit(X, y, **self.fit_params)
# Best score: 0.4226315365964312
# Best parameters: {'max_features': 'sqrt', 'n_estimators': 250}
# Time:  539.5460170626641  minutes

# %% [markdown]
# When we run above code, we could have next result:
#
# #### Best parameters: {'max_features': 'sqrt', 'n_estimators': 250}
#
# Best score: 0.4226315365964312
#
# Time:  539.5460170626641  minutes > 8 hours

# %% [markdown]
# ## III. Final Model

# %% [markdown]
# Setting our models with the values of the parameters obtained in the before step:

# %% [markdown]
# ### A.2 Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
# max_features:
# The number of features to consider when looking for the best split:
# If max_features = 'sqrt', then max_features=sqrt(n_features).
rfr_model = RandomForestRegressor(n_estimators=250, criterion='mse', random_state=100, n_jobs=-1, max_features = 'sqrt',
                                  min_samples_leaf=4, min_samples_split=8)

# %%
from time import time
time_star = time()

rfr_model.fit(X_train, y_train)

time_end = time()
print ("Time: ", np.round((time_end-time_star)/60,2), " minutes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# Time:  1.6  minutes

# %%
# Predict the target to our training and testing data
y_pred_rfr_train = rfr_model.predict(X_train)
y_pred_rfr = rfr_model.predict(X_test)

# %%
from sklearn import metrics
import numpy as np
print('Metrics for Training Set:')
print('MAE:', metrics.mean_absolute_error(y_train, y_pred_rfr_train))
print('MSE:', metrics.mean_squared_error(y_train, y_pred_rfr_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_rfr_train)))

print('\nMetrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_rfr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_rfr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_rfr)))
# Out:
# Metrics for Training Set:
# MAE: 1.13405267898
# MSE: 2.34096648521
# RMSE: 1.53002172704
#
# Metrics for Test Set:
# MAE: 1.48530504212
# MSE: 3.96996689933
# RMSE: 1.99247757813

# %% [markdown]
# ### B.2. Extra Tree Regression

# %%
from sklearn.ensemble import ExtraTreesRegressor

# Setting ExtraTreesRegressor parameters
etr_model = ExtraTreesRegressor(n_estimators=250, criterion='mse', random_state=100, n_jobs=-1, max_features = 'sqrt',
                                  min_samples_leaf=4, min_samples_split=8)

# %%
from time import time
time_star = time()
etr_model.fit(X_train, y_train)
time_end = time()
print ("Time: ", np.round((time_end-time_star)/60,2), " minutes")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()
# Time:  1.05  minutes

# %%
# Predict the target to our training and testing data
y_pred_etr_train = etr_model.predict(X_train)
y_pred_etr = etr_model.predict(X_test)

# %%
from sklearn import metrics
import numpy as np
print('Metrics for Training Set:')
print('MAE:', metrics.mean_absolute_error(y_train, y_pred_etr_train))
print('MSE:', metrics.mean_squared_error(y_train, y_pred_etr_train))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_train, y_pred_etr_train)))

print('\nMetrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred_etr))
print('MSE:', metrics.mean_squared_error(y_test, y_pred_etr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_etr)))
# Out:
# Metrics for Training Set:
# MAE: 1.30613412701
# MSE: 3.04343795822
# RMSE: 1.74454520097
#
# Metrics for Test Set:
# MAE: 1.48941371716
# MSE: 3.94587457389
# RMSE: 1.98642255673

# %% [markdown]
# ### C. Ensemble

# %% [markdown]
# Again, make a simple ensemble model with an simple average between the 2 predictions of our generated models:

# %%
y_pred = (y_pred_etr + y_pred_rfr)/2

# %%
print('\nMetrics for Test Set:')
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Metrics for Test Set:
# MAE: 1.48578154481
# MSE: 3.94673091613
# RMSE: 1.9866380939

# %% [markdown]
# Searching the best values for "a" and "b" coefficients:

# %%
# At begin(above) "a" and "b" were:
a = 1
b = 1
# Now, "a" and "b" coefficients will be from 1 until 10 
array_mrse = []
for a in range(1,11):
    for b in range(1,11):
        var_sum = a + b
        y_pred = (y_pred_etr*a + y_pred_rfr*b)/var_sum
        rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
        array_mrse.append([a,b,rmse])
pd.DataFrame(array_mrse, columns = ['a','b','mrse']).sort_values(by = ['mrse','a']).head(5)
# Out:
#      a  b      mrse
# 92  10  3  1.985822
# 61   7  2  1.985823
# 20   3  1  1.985826
# 51   6  2  1.985826
# 82   9  3  1.985826

# %% [markdown]
# Finally, we can see that best combination of coefficients are: a = 10 and b = 3 and this assembling improve(decreasing the RMSE) the individual models.

# %% [markdown]
# #### In conclusion, the final MRSE for our testing data is 1.9858

# %% [markdown]
# # IV. Summit

# %% [markdown]
# Merge features to the summit dataset

# %%
dataset_summit_temp = pd.merge(test_data, data_user, how="left", on = "userId")
dataset_summit = pd.merge(dataset_summit_temp, data_item, how="left", on = "itemId")
dataset_summit_temp = [] 
dataset_summit
# Out:
#                ID  userId  itemId  rat_count_user  rat_mean_user  \
# 0        16041_10   16041      10              29       5.862069
# 1       16041_107   16041     107              29       5.862069
# 2         16041_1   16041       1              29       5.862069
# 3        16041_40   16041      40              29       5.862069
# 4        16041_96   16041      96              29       5.862069
# 5       16041_137   16041     137              29       5.862069
# 6        16041_51   16041      51              29       5.862069
# 7        16041_59   16041      59              29       5.862069
# 8       16041_135   16041     135              29       5.862069
# 9        16041_15   16041      15              29       5.862069
# 10       16041_48   16041      48              29       5.862069
# 11       16041_83   16041      83              29       5.862069
# 12       16041_24   16041      24              29       5.862069
# 13       16041_77   16041      77              29       5.862069
# 14       16041_70   16041      70              29       5.862069
# 15      16041_121   16041     121              29       5.862069
# 16       16041_76   16041      76              29       5.862069
# 17      16041_109   16041     109              29       5.862069
# 18       16041_35   16041      35              29       5.862069
# 19      16041_128   16041     128              29       5.862069
# 20       16041_62   16041      62              29       5.862069
# 21      16041_127   16041     127              29       5.862069
# 22       16041_82   16041      82              29       5.862069
# 23      16041_108   16041     108              29       5.862069
# 24       56092_25   56092      25              13       7.000000
# 25       56092_10   56092      10              13       7.000000
# 26      56092_107   56092     107              13       7.000000
# 27       56092_47   56092      47              13       7.000000
# 28       56092_21   56092      21              13       7.000000
# 29       56092_63   56092      63              13       7.000000
# ...           ...     ...     ...             ...            ...
# 640985     1587_2    1587       2              71       7.683099
# 640986    1587_11    1587      11              71       7.683099
# 640987    1587_90    1587      90              71       7.683099
# 640988    1587_14    1587      14              71       7.683099
# 640989    1587_22    1587      22              71       7.683099
# 640990    1587_23    1587      23              71       7.683099
# 640991    1587_79    1587      79              71       7.683099
# 640992    1587_97    1587      97              71       7.683099
# 640993    1587_44    1587      44              71       7.683099
# 640994   1587_110    1587     110              71       7.683099
# 640995   1587_126    1587     126              71       7.683099
# 640996    1587_86    1587      86              71       7.683099
# 640997    1587_88    1587      88              71       7.683099
# 640998    1587_74    1587      74              71       7.683099
# 640999    1587_16    1587      16              71       7.683099
# 641000    1587_12    1587      12              71       7.683099
# 641001    1587_15    1587      15              71       7.683099
# 641002    1587_41    1587      41              71       7.683099
# 641003    1587_75    1587      75              71       7.683099
# 641004    1587_70    1587      70              71       7.683099
# 641005    1587_27    1587      27              71       7.683099
# 641006    1587_38    1587      38              71       7.683099
# 641007    1587_33    1587      33              71       7.683099
# 641008    1587_46    1587      46              71       7.683099
# 641009    1587_58    1587      58              71       7.683099
# 641010     1587_6    1587       6              71       7.683099
# 641011   1587_122    1587     122              71       7.683099
# 641012    1587_34    1587      34              71       7.683099
# 641013    1587_80    1587      80              71       7.683099
# 641014     1587_5    1587       5              71       7.683099
#
#         rat_median_user  rat_min_user  rat_max_user  rat_std_user  \
# 0                   5.5           0.5          10.0      3.390893
# 1                   5.5           0.5          10.0      3.390893
# 2                   5.5           0.5          10.0      3.390893
# 3                   5.5           0.5          10.0      3.390893
# 4                   5.5           0.5          10.0      3.390893
# 5                   5.5           0.5          10.0      3.390893
# 6                   5.5           0.5          10.0      3.390893
# 7                   5.5           0.5          10.0      3.390893
# 8                   5.5           0.5          10.0      3.390893
# 9                   5.5           0.5          10.0      3.390893
# 10                  5.5           0.5          10.0      3.390893
# 11                  5.5           0.5          10.0      3.390893
# 12                  5.5           0.5          10.0      3.390893
# 13                  5.5           0.5          10.0      3.390893
# 14                  5.5           0.5          10.0      3.390893
# 15                  5.5           0.5          10.0      3.390893
# 16                  5.5           0.5          10.0      3.390893
# 17                  5.5           0.5          10.0      3.390893
# 18                  5.5           0.5          10.0      3.390893
# 19                  5.5           0.5          10.0      3.390893
# 20                  5.5           0.5          10.0      3.390893
# 21                  5.5           0.5          10.0      3.390893
# 22                  5.5           0.5          10.0      3.390893
# 23                  5.5           0.5          10.0      3.390893
# 24                  7.5           0.0          10.0      3.391165
# 25                  7.5           0.0          10.0      3.391165
# 26                  7.5           0.0          10.0      3.391165
# 27                  7.5           0.0          10.0      3.391165
# 28                  7.5           0.0          10.0      3.391165
# 29                  7.5           0.0          10.0      3.391165
# ...                 ...           ...           ...           ...
# 640985              9.0           0.5          10.0      2.979980
# 640986              9.0           0.5          10.0      2.979980
# 640987              9.0           0.5          10.0      2.979980
# 640988              9.0           0.5          10.0      2.979980
# 640989              9.0           0.5          10.0      2.979980
# 640990              9.0           0.5          10.0      2.979980
# 640991              9.0           0.5          10.0      2.979980
# 640992              9.0           0.5          10.0      2.979980
# 640993              9.0           0.5          10.0      2.979980
# 640994              9.0           0.5          10.0      2.979980
# 640995              9.0           0.5          10.0      2.979980
# 640996              9.0           0.5          10.0      2.979980
# 640997              9.0           0.5          10.0      2.979980
# 640998              9.0           0.5          10.0      2.979980
# 640999              9.0           0.5          10.0      2.979980
# 641000              9.0           0.5          10.0      2.979980
# 641001              9.0           0.5          10.0      2.979980
# 641002              9.0           0.5          10.0      2.979980
# 641003              9.0           0.5          10.0      2.979980
# 641004              9.0           0.5          10.0      2.979980
# 641005              9.0           0.5          10.0      2.979980
# 641006              9.0           0.5          10.0      2.979980
# 641007              9.0           0.5          10.0      2.979980
# 641008              9.0           0.5          10.0      2.979980
# 641009              9.0           0.5          10.0      2.979980
# 641010              9.0           0.5          10.0      2.979980
# 641011              9.0           0.5          10.0      2.979980
# 641012              9.0           0.5          10.0      2.979980
# 641013              9.0           0.5          10.0      2.979980
# 641014              9.0           0.5          10.0      2.979980
#
#         rat_count_item  rat_mean_item  rat_median_item  rat_min_item  \
# 0                23706       4.693917              5.0           0.0
# 1                24107       4.197038              4.0           0.0
# 2                23934       5.377288              5.5           0.0
# 3                 6969       6.494332              7.0           0.0
# 4                 5071       5.647604              6.0           0.0
# 5                15353       6.779066              7.0           0.0
# 6                 4143       5.588342              6.0           0.0
# 7                 6643       6.283080              6.5           0.0
# 8                 5807       6.034441              6.0           0.0
# 9                 7191       6.210332              6.5           0.0
# 10                9260       6.463283              6.5           0.0
# 11               11523       6.739478              7.0           0.0
# 12                9726       6.475735              6.5           0.0
# 13                6564       5.992992              6.0           0.0
# 14                5453       6.239134              6.5           0.0
# 15               13358       6.768828              7.0           0.0
# 16                7695       6.214425              6.5           0.0
# 17                3124       4.898528              5.0           0.0
# 18               10190       6.633660              7.0           0.0
# 19               10179       6.516652              7.0           0.0
# 20                6159       6.287060              6.5           0.0
# 21                9921       6.661274              7.0           0.0
# 22                6794       5.967766              6.0           0.0
# 23                9470       6.600634              7.0           0.0
# 24               23844       4.677403              5.0           0.0
# 25               23706       4.693917              5.0           0.0
# 26               24107       4.197038              4.0           0.0
# 27               23891       4.935101              5.0           0.0
# 28                5957       6.079067              6.5           0.0
# 29                3273       5.554690              5.5           0.0
# ...                ...            ...              ...           ...
# 640985            7393       6.247531              6.5           0.0
# 640986            5603       5.819115              6.0           0.0
# 640987            8557       6.407327              6.5           0.0
# 640988            6543       5.979826              6.0           0.0
# 640989            5281       5.740485              6.0           0.0
# 640990           10800       6.414769              6.5           0.0
# 640991            6601       5.734510              6.0           0.0
# 640992            3434       5.208503              5.0           0.0
# 640993            5040       5.850794              6.0           0.0
# 640994            5085       5.583186              6.0           0.0
# 640995            6214       5.987850              6.0           0.0
# 640996            4437       6.086207              6.0           0.0
# 640997            4318       5.734252              6.0           0.0
# 640998            3568       5.900785              6.0           0.0
# 640999            9630       6.644860              7.0           0.0
# 641000            5082       6.101732              6.5           0.0
# 641001            7191       6.210332              6.5           0.0
# 641002            6464       6.420251              6.5           0.0
# 641003            5592       6.017525              6.5           0.0
# 641004            5453       6.239134              6.5           0.0
# 641005            5659       6.214172              6.5           0.0
# 641006            4046       5.540040              5.5           0.0
# 641007            3940       5.340102              5.5           0.0
# 641008            4193       5.786668              6.0           0.0
# 641009            5083       5.937537              6.0           0.0
# 641010            3319       5.293010              5.5           0.0
# 641011            3314       4.990193              5.0           0.0
# 641012            5094       5.900864              6.0           0.0
# 641013            3014       4.918879              5.0           0.0
# 641014            3028       4.777576              5.0           0.0
#
#         rat_max_item  rat_std_item
# 0               10.0      2.696327
# 1               10.0      2.689592
# 2               10.0      2.638525
# 3               10.0      2.548807
# 4               10.0      2.563235
# 5               10.0      2.345042
# 6               10.0      2.608309
# 7               10.0      2.380900
# 8               10.0      2.361113
# 9               10.0      2.514399
# 10              10.0      2.317587
# 11              10.0      2.206272
# 12              10.0      2.314274
# 13              10.0      2.557570
# 14              10.0      2.717878
# 15              10.0      2.235275
# 16              10.0      2.425768
# 17              10.0      2.958207
# 18              10.0      2.326288
# 19              10.0      2.402080
# 20              10.0      2.502223
# 21              10.0      2.342487
# 22              10.0      2.402981
# 23              10.0      2.192634
# 24              10.0      2.561905
# 25              10.0      2.696327
# 26              10.0      2.689592
# 27              10.0      2.550463
# 28              10.0      2.544261
# 29              10.0      2.503495
# ...              ...           ...
# 640985          10.0      2.425138
# 640986          10.0      2.843468
# 640987          10.0      2.327123
# 640988          10.0      2.592668
# 640989          10.0      2.597314
# 640990          10.0      2.395125
# 640991          10.0      2.495237
# 640992          10.0      2.627950
# 640993          10.0      2.470597
# 640994          10.0      2.605195
# 640995          10.0      2.582295
# 640996          10.0      2.480005
# 640997          10.0      2.638334
# 640998          10.0      2.656188
# 640999          10.0      2.508339
# 641000          10.0      2.728439
# 641001          10.0      2.514399
# 641002          10.0      2.470392
# 641003          10.0      2.722328
# 641004          10.0      2.717878
# 641005          10.0      2.509418
# 641006          10.0      2.564231
# 641007          10.0      2.599811
# 641008          10.0      2.515431
# 641009          10.0      2.588779
# 641010          10.0      2.763852
# 641011          10.0      2.675245
# 641012          10.0      2.546560
# 641013          10.0      2.619935
# 641014          10.0      2.979029
#
# [641015 rows x 15 columns]

# %%
print("Shape: {} \n".format(dataset_summit.shape))
dataset_summit.info()
# Out:
# Shape: (641015, 15)
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 641015 entries, 0 to 641014
# Data columns (total 15 columns):
# ID                 641015 non-null object
# userId             641015 non-null int64
# itemId             641015 non-null int64
# rat_count_user     641015 non-null int64
# rat_mean_user      641015 non-null float64
# rat_median_user    641015 non-null float64
# rat_min_user       641015 non-null float64
# rat_max_user       641015 non-null float64
# rat_std_user       641015 non-null float64
# rat_count_item     641015 non-null int64
# rat_mean_item      641015 non-null float64
# rat_median_item    641015 non-null float64
# rat_min_item       641015 non-null float64
# rat_max_item       641015 non-null float64
# rat_std_item       641015 non-null float64
# dtypes: float64(10), int64(4), object(1)
# memory usage: 78.2+ MB

# %%
X_dataset_summit = dataset_summit.ix[:, variables_set_x]
print ("Nro_Variables: ", len(X_dataset_summit.columns))
X_dataset_summit.columns
# Out:
# Nro_Variables:  12
# Index(['rat_count_user', 'rat_mean_user', 'rat_median_user', 'rat_min_user',
#        'rat_max_user', 'rat_std_user', 'rat_count_item', 'rat_mean_item',
#        'rat_median_item', 'rat_min_item', 'rat_max_item', 'rat_std_item'],
#       dtype='object')

# %% [markdown]
# ### Apply ensemble model on summit dataset:

# %%
y_pred_summiDS_etr = etr_model.predict(X_dataset_summit)
y_pred_summiDS_etr_df = pd.DataFrame(y_pred_summiDS_etr, columns = ['rating'])

# %%
y_pred_summiDS_rfr = rfr_model.predict(X_dataset_summit)
y_pred_summiDS_rfr_df = pd.DataFrame(y_pred_summiDS_rfr, columns = ['rating'])

# %%
a = 10
b = 3
sum_var = a + b
y_pred_summiDS = (y_pred_summiDS_etr_df*a + y_pred_summiDS_rfr_df*b)/sum_var

# %%
summit = pd.concat( [dataset_summit.ix[:,'ID'] , y_pred_summiDS ], axis = 1)

# %%
summit
# Out:
#                ID    rating
# 0        16041_10  4.252705
# 1       16041_107  3.551483
# 2         16041_1  5.342552
# 3        16041_40  6.568824
# 4        16041_96  5.387443
# 5       16041_137  7.278069
# 6        16041_51  5.358696
# 7        16041_59  5.568638
# 8       16041_135  5.113431
# 9        16041_15  5.925161
# 10       16041_48  6.575042
# 11       16041_83  6.716741
# 12       16041_24  6.593899
# 13       16041_77  6.226733
# 14       16041_70  5.548235
# 15      16041_121  7.019884
# 16       16041_76  6.275505
# 17      16041_109  4.572453
# 18       16041_35  6.701870
# 19      16041_128  6.466940
# 20       16041_62  5.625392
# 21      16041_127  7.053034
# 22       16041_82  5.656458
# 23      16041_108  6.168085
# 24       56092_25  5.666581
# 25       56092_10  4.969204
# 26      56092_107  4.482796
# 27       56092_47  4.539236
# 28       56092_21  7.062612
# 29       56092_63  6.516760
# ...           ...       ...
# 640985     1587_2  8.394964
# 640986    1587_11  7.568038
# 640987    1587_90  8.377160
# 640988    1587_14  7.808078
# 640989    1587_22  8.177259
# 640990    1587_23  8.206209
# 640991    1587_79  8.084206
# 640992    1587_97  6.753120
# 640993    1587_44  7.817575
# 640994   1587_110  7.812391
# 640995   1587_126  7.854298
# 640996    1587_86  8.317969
# 640997    1587_88  7.835979
# 640998    1587_74  7.665428
# 640999    1587_16  8.321192
# 641000    1587_12  7.810656
# 641001    1587_15  8.045060
# 641002    1587_41  8.089968
# 641003    1587_75  7.965500
# 641004    1587_70  8.138355
# 641005    1587_27  7.607628
# 641006    1587_38  6.935013
# 641007    1587_33  6.322009
# 641008    1587_46  6.953263
# 641009    1587_58  7.668960
# 641010     1587_6  6.231305
# 641011   1587_122  5.734319
# 641012    1587_34  7.838919
# 641013    1587_80  5.622683
# 641014     1587_5  4.854044
#
# [641015 rows x 2 columns]

# %%
summit.to_csv("C:/Users/b33580/Documents/Python Scripts/MLWARE/TEST/submission_MLWARE2_ensenmble.csv")

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Autor: Keven Ronald Fernández Carrillo ( A passionate newbie in machine learning topics )
